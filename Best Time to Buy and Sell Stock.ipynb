# %% [markdown]
# Say you have an array for which the ith element is the price of a given stock on day i.
#
# If you were only permitted to complete at most one transaction (i.e., buy one and sell one share of the stock), design an algorithm to find the maximum profit.
#
# Note that you cannot sell a stock before you buy one.

# %% [markdown]
# ![Screen%20Shot%202019-11-16%20at%202.58.15%20PM.png](attachment:Screen%20Shot%202019-11-16%20at%202.58.15%20PM.png)

# %% [markdown]
# My Solution (Time Limit Exceeded):

# %%
prices1 = [7,1,5,3,6,4]
prices2 = [7,6,4,3,1]
prices3 = [2,4,1]
prices4 = []

# %%
def maxProfit(prices):
    if prices == []:
        return 0
    max_profit = []
    length = len(prices)
    for i in range(len(prices)):
        if i >= length:
            return 0
        else:
            max_price = max(prices[i:])
            profit = max_price - prices[i]
            max_profit.append(profit)
    return max(max_profit)

# %%
maxProfit(prices1)
# Out:
# 5

# %%
maxProfit(prices2)
# Out:
# 0

# %%
maxProfit(prices3)
# Out:
# 2

# %%
maxProfit(prices4)
# Out:
# 0

# %% [markdown]
# Revised Solution:

# %%
def maxProfit(prices):
    if prices == []:
        return 0
    curr_max=0
    min_curr=prices[0]
    for i in range(1, len(prices)):
        if prices[i] <= prices[i-1]:
            min_curr= min(prices[i], min_curr)       
        if prices[i] > prices[i-1]:
            curr_max = max(curr_max, prices[i]-min_curr)
    return curr_max

# %% [markdown]
# - Runtime: 68 ms, faster than 88.65% of Python3 online submissions for Best Time to Buy and Sell Stock.
# - Memory Usage: 13.9 MB, less than 81.61% of Python3 online submissions for Best Time to Buy and Sell Stock.

# %%
maxProfit(prices1)
# Out:
# 5

# %%
maxProfit(prices2)
# Out:
# 0

# %%
maxProfit(prices3)
# Out:
# 2

# %%
maxProfit(prices4)
# Out:
# 0
